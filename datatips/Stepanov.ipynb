# %% [markdown]
# Большая часть трафика на сайт приходит с мобильных устройств, это важно.
#
# Используя любые средства и методы необходимо изучить данные и попытаться ответить на вопрос "Что не так с конверсией?". Артефактом задания является jupyter-ноутбук и сформированный в выводах ответ или перечень гипотез.
#
# Дедлайна нет, но чтобы мы могли обеспечить качественный фидбек - просьба сообщить https://t.me/lexachatsky когда вам будет удобно прислать задание.

# %%
import pandas as pd

d1=pd.read_csv('Amplitude test events - Events.csv',sep=',')

d2=pd.read_csv('amplitude_test.csv')

# %%
d1
# Out:
#     Properties are hidden!          Unnamed: 1  \
# 0                      NaN                 NaN
# 1                   Events                 NaN
# 2           Event Category          Event Name
# 3                   Browse    Home page viewed
# 4                   Browse  Configurator start
# ..                     ...                 ...
# 111                    NaN                 NaN
# 112              Post-sale   Track order press
# 113              Post-sale     Track order put
# 114                General    changed language
# 115                General           gift card
#
#                             Unnamed: 2     Unnamed: 3       Unnamed: 4  \
# 0                                  NaN            NaN              NaN
# 1                                  NaN     Properties              NaN
# 2          Trigger + Event Description  Property Type    Property Name
# 3                                  NaN            NaN              NaN
# 4                                  NaN            NaN            point
# ..                                 ...            ...              ...
# 111                                NaN            NaN       error code
# 112   Нажата клавиша "отследить заказ"            NaN              NaN
# 113  введен ID заказа для отслеживания            NaN               ID
# 114                                NaN            NaN     new language
# 115                                NaN            NaN  amount of money
#
#         Unnamed: 5
# 0              NaN
# 1              NaN
# 2    Sample Values
# 3              NaN
# 4    header; title
# ..             ...
# 111            NaN
# 112            NaN
# 113            NaN
# 114            NaN
# 115            NaN
#
# [116 rows x 6 columns]
